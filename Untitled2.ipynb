# %%
a = float(input("Nhập hệ số a: "))
b = float(input("Nhập hệ số b: "))
c = float(input("Nhập hệ số c: "))
d =b*b -a*c*4
#neu d<0 thi ptvn
#neu d=0 thi pt co 1 nghiem
#pt co 2 nghiem phan biet
if d<0:
   print("phuong trinh vo nghiem")
elif d==0:
    print(f"Phương trình có 1 nghiệm:",-b/(2*a))
else:
    print("Phương trình có 2 nghiệm:")
    x1=(-b+d**0.5/2*a)
    x2=(-b-d**0.5/2*a)
    print("x1=",x1)
    print("x2=",x2)
# Out:
# Nhập hệ số a: 2
# Nhập hệ số b: 6
# Nhập hệ số c: 7
# phuong trinh vo nghiem
